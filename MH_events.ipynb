# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

import mineut
from mineut import plot_tools as pt
from mineut import lattice_tools as lt

from mineut.MuC import MuDecaySimulator

# %% [markdown]
# ## Linear Accelerator

# %%
PA_numu = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='numu',
    direction="right",
    n_evals=1e6,
    )

PA_nue = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='nue',
    direction="right",
    n_evals=1e6,
    )

PA_numu.decay_muons()
PA_nue.decay_muons()

# %%
straight_lattice = lt.create_straight_lattice(
            name= r"PA",
            short_name= "pa",
            total_length=160e2,
            n_elements=100_000,
            beamdiv=1e-3,
            beamdiv_z=1e-2,
            beamsize=1,
            Nmu_per_bunch=2e12,
        )
# Out:
# Setting additional z to <scipy.interpolate._interpolate.interp1d object at 0x17e282d50>
# Setting additional tangent to <function create_lattice_dict_from_vertices.<locals>.<lambda> at 0x121563740>
# Warning! The following keys were not recognized and will be ignored: dict_keys(['z', 'tangent'])

# %%
PA_numu.place_muons_on_lattice(lattice=straight_lattice, direction="clockwise")
PA_nue.place_muons_on_lattice(lattice=straight_lattice, direction="clockwise")

plt.scatter(straight_lattice.vertices[0], straight_lattice.vertices[1], c='black', marker='+', s=10)
plt.scatter(PA_numu.pos['z'], PA_numu.pos['y'], marker='.', s=0.1)
plt.ylim(-1000, 1000)
plt.xlabel('Z (cm)')
plt.ylabel('Y (cm)')
plt.gca().set_aspect('equal', adjustable='box')
# Out:
# sample_size: 937463
# pos x range: -5.304833991814324 0.0009148794846471542 5.004777922950793
# pos y range: -5.045090450595604 -0.0017534176104559468 4.526081104423541
# pos z range: -7999.97764010671 4.7497067769124754 7999.99656371935
# s_in_turn min/max: 0.022359893289802812 15999.996563719349
# u_parameter min/max: 1.3974933306126758e-06 0.9999997852324594
# mutimes min/max: 8.232891343676414e-13 5.357008108867134e-07
# muon_lifetime min/max: 5.030394931943435e-06 2.7058546636576682e-05
# sample_size: 937761
# pos x range: -4.724571963702143 0.0006284718676143087 4.576068301052561
# pos y range: -4.592476497519624 0.0015649583177645091 4.845979774859568
# pos z range: -7999.9517419233325 -14.785284820938058 7999.983105122266
# s_in_turn min/max: 0.04825807666719584 15999.983105122266
# u_parameter min/max: 3.01612979169974e-06 0.9999989440701417
# mutimes min/max: 1.7839150633969902e-12 5.356811939131354e-07
# muon_lifetime min/max: 5.047046189394826e-06 2.69988966838764e-05

# %%
plt.scatter(straight_lattice.vertices[0]/100, straight_lattice.vertices[1]/100, c='black', marker='+', s=10)
#plt.scatter(PA_numu.pos['z'], PA_numu.pos['y'], marker='.', s=0.1)
plt.ylim(-10, 10)
plt.xlabel('Z (m)')
plt.ylabel('X (m)')
plt.title("PA")
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## RLA1

# %%
RLA1_numu = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='numu',
    direction="right",
    n_evals=1e6,
    )

RLA1_nue = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='nue',
    direction="right",
    n_evals=1e6,
    )

RLA1_numu.decay_muons()
RLA1_nue.decay_muons()

# %%
RLA1_lattice = lt.create_RLA_lattice(
            name = r"RLA1",
            short_name= "rla1",
            straight_length=70e2,
            n_elements=100_000,
            p0_injection=1.25,
            dp_dx_LA=0.84/70e2,
            beamdiv=1e-3,
            beamdiv_z=1e-2,
            beamsize=1e-2,
            Nmu_per_bunch=2e12,
        )
# Out:
# [2157.68       2157.80349264 2157.92698528 ...    0.            0.
#     0.        ]
# Setting additional z to <scipy.interpolate._interpolate.interp1d object at 0x17f293700>
# Setting additional tangent to <function create_lattice_dict_from_vertices.<locals>.<lambda> at 0x17f29b7e0>
# Setting additional beamdiv to 0.001
# Setting additional beamsize to 0.01
# Warning! The following keys were not recognized and will be ignored: dict_keys(['z', 'tangent', 'beamdiv', 'beamsize'])
# /Users/mhostert/Repos/MINT/mineut/lattice_tools.py:559: RuntimeWarning: divide by zero encountered in divide
#   beamdiv = np.where(beta < 1.0, beta, np.sqrt(emittance / beta))

# %%
RLA1_nue.place_muons_on_lattice(lattice=RLA1_lattice, direction="clockwise")
RLA1_numu.place_muons_on_lattice(lattice=RLA1_lattice, direction="clockwise")

max_index = len(RLA1_lattice.vertices[1])

fig, ax = pt.std_fig(figsize=(5, 2))
ax.scatter(RLA1_lattice.vertices[0], RLA1_lattice.vertices[1], c=np.linspace(0,1,max_index), marker='+', s=10)
ax.scatter(RLA1_numu.pos['z'], RLA1_numu.pos['x'], marker='.', s=0.25)

fig.gca().set_aspect('equal', adjustable='box')

ax.set_xlabel("z [cm]")
ax.set_ylabel("y [cm]")
ax.set_title("RLA 1")
# Out:
# sample_size: 937681
# pos x range: -2744.8466750169655 -1.535840444095378 2744.846374675565
# pos y range: -38.627633633102796 -0.005514674937202897 39.07773567445566
# pos z range: -13088.960860165247 -463.0531164930625 12104.972900343524
# s_in_turn min/max: 0.06155961439053407 120044.99343737632
# u_parameter min/max: 5.128028720546851e-07 0.9999968001738865
# mutimes min/max: 2.060523997414273e-12 4.0051628310563105e-06
# muon_lifetime min/max: 2.5336901809866193e-05 0.00010789124577144745
# sample_size: 937429
# pos x range: -2744.8468308080714 -1.889498253560286 2744.8463150943517
# pos y range: -37.846430462128914 -0.006112277943355679 42.19515067941432
# pos z range: -13088.960860165247 -457.9785811639894 12105.843102125591
# s_in_turn min/max: 0.04601800917536752 120045.35429056828
# u_parameter min/max: 3.8333845175930753e-07 0.9999998061471217
# mutimes min/max: 1.5403987418386096e-12 4.005186682488814e-06
# muon_lifetime min/max: 2.5476686714335083e-05 0.0001082419298686554
# Text(0.5, 1.0, 'RLA 1')

# %%
fig, ax = pt.std_fig(figsize=(5, 2))
ax.scatter(RLA1_lattice.vertices[0]/100, RLA1_lattice.vertices[1]/100, marker='.', s=10)

fig.gca().set_aspect('equal', adjustable='box')

ax.set_xlabel("x [m]")
ax.set_ylabel("y [m]")
ax.set_title("RLA 1")
# Out:
# Text(0.5, 1.0, 'RLA 1')

# %% [markdown]
# ## RLA2

# %%
RLA2_numu = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='numu',
    direction="right",
    n_evals=1e6,
    )

RLA2_nue = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='nue',
    direction="right",
    n_evals=1e6,
    )

RLA2_numu.decay_muons()
RLA2_nue.decay_muons()

# %%
RLA2_lattice = lt.create_RLA_lattice(
            name = r"RLA2",
            short_name= "rla2",
            straight_length=829e2,
            n_elements=100_000,
            p0_injection=5.0,
            dp_dx_LA=11.6/829e2,
            beamdiv=1e-3,
            beamdiv_z=1e-2,
            beamsize=1e-2,
            half=False,
            Nmu_per_bunch=2e12,
)
# Out:
# [ 2157.68        2160.60501144  2163.53002288 ... 17587.56156373
#  17590.48657517 17593.4115866 ]
# Setting additional z to <scipy.interpolate._interpolate.interp1d object at 0x17f5da990>
# Setting additional tangent to <function create_lattice_dict_from_vertices.<locals>.<lambda> at 0x17f576520>
# Setting additional beamdiv to 0.001
# Setting additional beamsize to 0.01
# Warning! The following keys were not recognized and will be ignored: dict_keys(['z', 'tangent', 'beamdiv', 'beamsize'])
# /Users/mhostert/Repos/MINT/mineut/lattice_tools.py:559: RuntimeWarning: divide by zero encountered in divide
#   beamdiv = np.where(beta < 1.0, beta, np.sqrt(emittance / beta))

# %%
# u ranges from 0 → 1
u_vals = np.linspace(0, 1, 2000)

# Convert to actual s-position (in cm):
s_vals = u_vals * 1463126.8482550883   # or lattice.length

fig, ax = plt.subplots(figsize=(6,4))
ax.plot(s_vals, RLA2_lattice.beamsize_x(u_vals), linewidth=1.0)

ax2 = ax.twinx()
ax2.plot(s_vals, RLA2_lattice.beamdiv_x(u_vals), color="red")

ax.set_xlabel("s [cm]")
ax.set_ylabel("beam_size_x [cm]")
ax2.set_ylabel("beam_div_x [cm]")
ax.set_title("Beam Dynamics Along RLA2 Lattice")
plt.tight_layout()
plt.show()

# %%
RLA2_nue.place_muons_on_lattice(lattice=RLA2_lattice, direction="clockwise")
RLA2_numu.place_muons_on_lattice(lattice=RLA2_lattice, direction="clockwise")

max_index = len(RLA2_lattice.vertices[1])

fig, ax = pt.std_fig(figsize=(5, 2))
ax.scatter(RLA2_lattice.vertices[0], RLA2_lattice.vertices[1], c=np.linspace(0, 1, max_index), marker='+', s=10)
ax.scatter(RLA2_numu.pos['z'], RLA2_numu.pos['x'], marker='.', s=0.25)

fig.gca().set_aspect('equal', adjustable='box')

ax.set_xlabel("z [cm]")
ax.set_ylabel("y [cm]")
ax.set_title("RLA 2")
# Out:
# sample_size: 937747
# pos x range: -32506.818415007274 34.03233211345384 32506.81360896186
# pos y range: -83.6338436189427 -0.0008329419727853284 103.62834255644526
# pos z range: -155010.69361538556 -5830.488112113054 143052.36193160593
# s_in_turn min/max: 0.38289948413587616 1463128.613826944
# u_parameter min/max: 2.61698835268831e-07 0.9999988768622484
# mutimes min/max: 1.2775003474313578e-11 4.8804788726522525e-05
# muon_lifetime min/max: 0.0001020514451475503 0.0013521122140491323
# sample_size: 937584
# pos x range: -32506.82307199228 -5.746880115212345 32506.813000731465
# pos y range: -92.4179061469031 0.0006668535759693123 97.61414387772906
# pos z range: -155010.69361538556 -5977.890248724232 143052.36193160593
# s_in_turn min/max: 1.9061268536051208 1463127.3718628117
# u_parameter min/max: 1.302773177114247e-06 0.9999980280218077
# mutimes min/max: 6.359546403186272e-11 4.8804744828774994e-05
# muon_lifetime min/max: 0.00010169309870754349 0.001358007777863344
# Text(0.5, 1.0, 'RLA 2')

# %%
fig, ax = pt.std_fig(figsize=(5, 2))
ax.scatter(RLA2_numu.pos['z']/100, RLA2_numu.pos['x']/100, marker='.', s=0.25)
ax.set_xlabel("z [m]")
ax.set_ylabel("x [m]")
ax.set_title("RLA 2")
# Out:
# Text(0.5, 1.0, 'RLA 2')

# %%
x, y, z = RLA2_lattice.vertices     # vertices were assigned at the end of create_RLA_lattice
np.savez("RLA2_geometry_points.npz", x_RLA=x, y_RLA=y)

# %%
def plot_avgE_vs_time(MuC_acc_numu, MuC_acc_nue):
    # Bin mutimes and compute average neutrino energy in each bin
    bins = np.linspace(MuC_acc_numu.mutimes.min(), MuC_acc_numu.mutimes.max(), 50)
    digitized = np.digitize(MuC_acc_numu.mutimes, bins)
    avg_mu_E = [MuC_acc_numu.pmu['E'][digitized == i].mean() if np.any(digitized == i) else np.nan for i in range(1, len(bins))]
    avg_numu_E = [MuC_acc_numu.pnu['E'][digitized == i].mean() if np.any(digitized == i) else np.nan for i in range(1, len(bins))]
    bins = np.linspace(MuC_acc_nue.mutimes.min(), MuC_acc_nue.mutimes.max(), 50)
    digitized = np.digitize(MuC_acc_nue.mutimes, bins)
    avg_nue_E = [MuC_acc_nue.pnu['E'][digitized == i].mean() if np.any(digitized == i) else np.nan for i in range(1, len(bins))]

    fig, ax = pt.std_fig(figsize=(4,3))
    ax.step(1e6*bins[:-1], avg_mu_E, linestyle='-', color='grey', label=r'$\langle E_{\mu} \rangle$')
    ax.step(1e6*bins[:-1], avg_nue_E, linestyle='-', color='darkorange', label=r'$\langle E_{\nu_e} \rangle$')
    ax.step(1e6*bins[:-1], avg_numu_E, linestyle='-', color='dodgerblue', label=r'$\langle E_{\nu_\mu} \rangle$')
    ax.set_xlabel('time ($\mu$s)')
    ax.set_ylabel(r'Average neutrino energy [GeV]')
    ax.legend(frameon=False, loc='upper left')
    return fig, ax

# %%
plot_avgE_vs_time(RLA1_numu, RLA1_nue)
plot_avgE_vs_time(RLA2_numu, RLA2_nue)
plot_avgE_vs_time(PA_numu, PA_nue)
# Out:
# (<Figure size 400x300 with 1 Axes>,
#  <Axes: xlabel='time ($\\mu$s)', ylabel='Average neutrino energy [GeV]'>)

# %% [markdown]
# ## Combine the Accelerators

# %%
combined_numu = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='numu',
    direction="right",
    n_evals=1e6,
    )

combined_nue = MuDecaySimulator(
    muon_polarization=0.0,
    nuflavor='nue',
    direction="right",
    n_evals=1e6,
    )

combined_numu.decay_muons()
combined_nue.decay_muons()

# %%
combined_lattice =lt.append_lattices(
    lt.append_lattices(
            straight_lattice,
            RLA1_lattice,
            -20e2,
            -29.11e2),
    RLA2_lattice,
    -20e2,
    1550.1e2-165.89e2
)
# Out:
# Setting additional z to <scipy.interpolate._interpolate.interp1d object at 0x17f471a90>
# Setting additional tangent to <function create_lattice_dict_from_vertices.<locals>.<lambda> at 0x17f7ed080>
# Warning! The following keys were not recognized and will be ignored: dict_keys(['z', 'tangent'])
# is same; lattice nmu per bunch is: 2000000000000.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 combined_lattice =lt.append_lattices(
#       2     lt.append_lattices(
#       3             straight_lattice,
#       4             RLA1_lattice,
#       5             -20e2,
#       6             -29.11e2),
#       7     RLA2_lattice,
#       8     -20e2,
#       9     1550.1e2-165.89e2
#      10 )
#
# File ~/Repos/MINT/mineut/lattice_tools.py:607, in append_lattices(lattice1, lattice2, vert_shift, hor_shift, p0_injection, Nmu_per_bunch_inj, **kwargs)
#     595 def append_lattices(
#     596     lattice1,
#     597     lattice2,
#    (...)
#     605
#     606     # Extract vertex arrays (support 2D or 3D vertex tuples)
# --> 607     xvals = lattice1.vertices[0]
#     608     yvals = lattice1.vertices[1]
#     609     zvals = lattice1.vertices[2] if len(lattice1.vertices) > 2 else np.zeros_like(xvals)
#
# AttributeError: 'NoneType' object has no attribute 'vertices'

# %%
combined_nue.place_muons_on_lattice(lattice=combined_lattice, direction="clockwise")
combined_numu.place_muons_on_lattice(lattice=combined_lattice, direction="clockwise")

max_index = len(combined_lattice.vertices[1])

fig, ax = pt.std_fig(figsize=(5, 2))
ax.scatter(combined_lattice.vertices[0], combined_lattice.vertices[1], c=np.linspace(0,1,max_index), marker='+', s=10)
ax.scatter(combined_numu.pos['z'], combined_numu.pos['x'], marker='.', s=0.25)

fig.gca().set_aspect('equal', adjustable='box')

ax.set_xlabel("z [cm]")
ax.set_ylabel("y [cm]")
ax.set_title("Combined Accelerators")
# Out:
# sample_size: 937643
# pos x range: -32506.776248529506 -23.80166092692786 32506.79919069682
# pos y range: -4000.0 -3759.3996471704872 0.0
# pos z range: -15000.693615385564 118736.87106085966 283062.36193160596
# s_in_turn min/max: 5.864145412525228 1699697.509447213
# u_parameter min/max: 3.450107968427929e-06 0.9999990635866086
# mutimes min/max: 2.1168767756556346e-10 5.669588582148361e-05
# muon_lifetime min/max: 5.746629934395698e-06 0.0013107836719533177
# sample_size: 937539
# pos x range: -32506.77608183083 -21.42165076798263 32506.79257526161
# pos y range: -4000.0 -3757.1997566235123 0.0
# pos z range: -15000.693615385564 118667.73405020934 283062.36193160596
# s_in_turn min/max: 0.07902060607256477 1699697.3258752231
# u_parameter min/max: 4.6490938321319675e-08 0.9999989555839687
# mutimes min/max: 2.8531425452681217e-12 5.669587969823741e-05
# muon_lifetime min/max: 5.7395125127887735e-06 0.001310783138037246
# Text(0.5, 1.0, 'Combined Accelerators')

# %%
fig, ax = pt.std_fig(figsize=(5, 2))
ax.scatter(combined_numu.pos['z']/1e5, combined_numu.pos['y']/1e5, marker='.', s=0.25)
ax.set_xlabel("z [km]")
ax.set_ylabel("y [km]")
ax.set_title(combined_lattice.name)
# Out:
# Text(0.5, 1.0, 'PA+RLA1+RLA2')

# %%
plot_avgE_vs_time(combined_numu,combined_nue)
# Out:
# (<Figure size 400x300 with 1 Axes>,
#  <Axes: xlabel='time ($\\mu$s)', ylabel='Average neutrino energy [GeV]'>)

# %% [markdown]
# ## Event Maps

# %%
X, Y, event_map = combined_numu.get_event_map_fixed_z(
    detect_loc=[(85e2, 0)],
    xrange=(-500,500),  
    yrange=(-5e2, 5e2),      
    nx=30,
    ny=30,
    det_radius=5e2              # 10m detector
)

# Visualization
# plt.figure(figsize=(6, 5))
# c = plt.pcolormesh(X, Y, event_map.T, shading='auto', cmap='Blues', vmin=1e-10)
# plt.colorbar(c, label='Detector Events (per year)')
# plt.xlabel('X Position [cm]')
# plt.ylabel('Y Position [cm]')
# plt.title(f"Neutrino Event Map for PA")
# plt.tight_layout()
# plt.show()

import matplotlib.ticker as ticker

plt.figure(figsize=(6, 5))
c = plt.pcolormesh(X, Y, event_map.T, shading='auto', cmap='Blues', vmin=1e-10)
cb = plt.colorbar(c, label='Detector Events (per year)')

# Force scientific notation on the colorbar
cb.formatter = ticker.ScalarFormatter()
cb.formatter.set_powerlimits((-2, 2))   # scientific notation outside [-2, 2]
cb.update_ticks()

plt.xlabel('X Position [cm]')
plt.ylabel('Y Position [cm]')
plt.title("Neutrino Event Map for PA")
plt.tight_layout()
plt.show()

# %%
X, Y, event_map = combined_numu.get_event_map_fixed_z(
    detect_loc=[(91.6821e2, 20e2)],
    #detect_loc=[(1e5, 20e2)],
    xrange=(-500,500),  
    yrange=(-22.5e2, -17.5e2),      
    nx=100,
    ny=100,
    det_radius=1.5e2              # 10m detector
)

# Visualization
plt.figure(figsize=(6, 5))
c = plt.pcolormesh(X, Y, event_map.T, shading='auto', cmap='Reds', vmin=0)
plt.colorbar(c, label='Detector Events (per bunch)')
plt.xlabel('X Position [cm]')
plt.ylabel('Y Position [cm]')
plt.title(f"Neutrino Event Map for RLA1")
plt.tight_layout()
plt.show()

# %%
X, Y, event_map = combined_numu.get_event_map_fixed_z(
    detect_loc=[(2835.62e2, 40e2)],
    xrange=(-500,500),  
    yrange=(-45e2, -35e2),      
    nx=30,
    ny=30,
    det_radius=5e2              # 10m detector
)

# Visualization
plt.figure(figsize=(4.5, 3.5))
c = plt.pcolormesh(X, Y, event_map.T, shading='auto', cmap='Blues', vmin=0)
cb = plt.colorbar(c, label='Detector Events (per year)')

cb.formatter = ticker.ScalarFormatter()
cb.formatter.set_powerlimits((-2, 2))   # scientific notation outside [-2, 2]
cb.update_ticks()

plt.xlabel('X Position [cm]')
plt.ylabel('Y Position [cm]')
plt.title(f"Neutrino Event Map for RLA2")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 21
#      19 plt.xlabel('X Position [cm]')
#      20 plt.ylabel('Y Position [cm]')
# ---> 21 plt.title(f"Neutrino Event Map for RLA2")
#      22 plt.tight_layout()
#      23 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Number of $\mu$ decays vs. t

# %%
print(sum(combined_numu.weights[combined_numu.s_muon<=160e2,0]))

print(sum(combined_numu.weights[combined_numu.s_muon<=139576.5707264804,0]))

print(sum(combined_numu.weights[:,0]))
# Out:
# 80184014184.27075
# 221280581681.21497
# 437505018054.7552

# %%
# --- helper: cumulative weights vs muon decay time (ns) ---
def plot_cumulative_weights_vs_time(MuC_acc_numu, MuC_acc_nue=None, show_fraction=True, figsize=(5,3)):
    """Plot cumulative sum of weights vs muon decay time (converted to ns).
    If `MuC_acc_nue` is provided it will be plotted alongside `MuC_acc_numu`.
    Returns (fig, ax).
    """
    import numpy as np
    import matplotlib.pyplot as plt
    # primary (numu)
    t1 = np.asarray(MuC_acc_numu.mutimes)
    w1 = np.asarray(MuC_acc_numu.weights)
    if w1.ndim > 1:
        w1 = w1[:, 0]
    order1 = np.argsort(t1)
    t1s = t1[order1]
    cum1 = np.cumsum(w1[order1])
    # optional second (nue)
    if MuC_acc_nue is not None:
        t2 = np.asarray(MuC_acc_nue.mutimes)
        w2 = np.asarray(MuC_acc_nue.weights)
        if w2.ndim > 1:
            w2 = w2[:, 0]
        order2 = np.argsort(t2)
        t2s = t2[order2]
        cum2 = np.cumsum(w2[order2])
    else:
        t2s = None
        cum2 = None
    # plot
    fig, ax = plt.subplots(figsize=figsize)
    ax.plot(1e6 * t1s, cum1, label='numu cumulative', color='C0')
    if cum2 is not None:
        ax.plot(1e6 * t2s, cum2, label='nue cumulative', color='C1')
    ax.set_xlabel('time ($\mu$s)')
    ax.set_ylabel('Number of decays (cumulative)')
    ax.set_title('Number of Decays vs Time')
    ax.grid(True)
    if show_fraction:
        ax2 = ax.twinx()
        total1 = 2e12  # total muons per bunch (or sum of weights if you prefer)
        ax2.plot(1e6 * t1s, cum1 / total1, color='C0', linestyle='--', alpha=0.8, label='numu fraction')
        if cum2 is not None:
            total2 = 2e12  # total muons per bunch (or sum of weights if you prefer)
            ax2.plot(1e6 * t2s, cum2 / total2, color='C1', linestyle='--', alpha=0.8, label='nue fraction')
        ax2.set_ylabel('Fraction of total \n (with respect to Nmu per bunch)')

    fig.tight_layout()

    fig.savefig('plots/num_decays_vs_time.pdf', bbox_inches='tight')
    return fig, ax

# Example calls (uncomment to run)
# plot_cumulative_weights_vs_time(RLA1_numu, RLA1_nue)
# plot_cumulative_weights_vs_time(RLA2_numu, RLA2_nue)
# plot_cumulative_weights_vs_time(PA_numu, PA_nue)

# %%
plot_cumulative_weights_vs_time(combined_numu)
# Out:
# (<Figure size 500x300 with 2 Axes>,
#  <Axes: title={'center': 'Number of Decays vs Time'}, xlabel='time ($\\mu$s)', ylabel='Number of decays (cumulative)'>)

# %%
combined_numu.plot_event_counts_vs_time([(90e2, 0),(120.7921e2-29.11e2, 20e2),(2830.62e2, 40e2)])
# Out:
# (<Figure size 600x300 with 1 Axes>,
#  <Axes: xlabel='muon time (ns)', ylabel='Predicted neutrino events'>)

# %%
combined_numu.plot_event_counts_vs_energy([(90e2, 0)], e_bins=np.geomspace(1e-3,2,30))
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='Neutrino Energy (GeV)', ylabel='Predicted neutrino events'>)

# %%
combined_numu.plot_event_counts_vs_energy([(120.7921e2-29.11e2, 20e2)])
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='Neutrino Energy (GeV)', ylabel='Predicted neutrino events'>)

# %%
fig, ax = combined_numu.plot_event_counts_vs_energy([(2835.62e2, 40e2)], det_radius=5e2, e_bins=np.geomspace(1e-2, 70, 30))
combined_numu.plot_event_counts_vs_energy([(91.6821e2, 20e2)], det_radius=1.5e2, e_bins=np.geomspace(1e-2, 70, 30), fig_and_ax=(fig, ax))
combined_numu.plot_event_counts_vs_energy([(85e2, 0)], det_radius=5e2, e_bins=np.geomspace(1e-2, 70, 30), fig_and_ax=(fig, ax),ylabel="dN/dE (per year)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 fig, ax = combined_numu.plot_event_counts_vs_energy([(2835.62e2, 40e2)], det_radius=5e2, e_bins=np.geomspace(1e-2, 70, 30),)
#       2 combined_numu.plot_event_counts_vs_energy([(91.6821e2, 20e2)], det_radius=1.5e2, e_bins=np.geomspace(1e-2, 70, 30), fig_and_ax=(fig, ax))
#       3 combined_numu.plot_event_counts_vs_energy([(85e2, 0)], det_radius=5e2, e_bins=np.geomspace(1e-2, 70, 30), fig_and_ax=(fig, ax),ylabel="dN/dE (per year)")
#
# ValueError: too many values to unpack (expected 2)

# %%
fig, ax, _ = combined_numu.plot_event_counts_vs_energy(
    detect_loc=[(85e2, 0)],
    det_radius=5e2,
    e_bins=np.geomspace(1e-2, 70, 30),
    color="green",
    label="PA",
)

combined_numu.plot_event_counts_vs_energy(
    detect_loc=[(91.6821e2, 20e2)],
    det_radius=1.5e2,
    e_bins=np.geomspace(1e-2, 70, 30),
    fig_and_ax=(fig, ax),
    color="red",
    label="RLA1"
)


combined_numu.plot_event_counts_vs_energy(
    detect_loc=[(2835.62e2, 40e2)],
    det_radius=5e2,
    e_bins=np.geomspace(1e-2, 70, 30),
    fig_and_ax=(fig, ax),
    color="blue",
    label="RLA2",
    ylabel="E dN/dE (per year)"
)


ax.legend()
ax.set_ylim(bottom=1e4) 
fig.suptitle("Time Integrated Event Rate at Each Accelerator Complex\n (with \"realistic\" detector placement)")
plt.show()

fig.savefig('plots/event_rate_spectrum.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 fig, ax, _ = combined_numu.plot_event_counts_vs_energy(
#       2     detect_loc=[(85e2, 0)],
#       3     det_radius=5e2,
#       4     e_bins=np.geomspace(1e-2, 70, 30),
#       5     color="green",
#       6     label="PA",
#       7 )
#       9 combined_numu.plot_event_counts_vs_energy(
#      10     detect_loc=[(91.6821e2, 20e2)],
#      11     det_radius=1.5e2,
#    (...)
#      15     label="RLA1"
#      16 )
#      19 combined_numu.plot_event_counts_vs_energy(
#      20     detect_loc=[(2835.62e2, 40e2)],
#      21     det_radius=5e2,
#    (...)
#      26     ylabel="E dN/dE (per year)"
#      27 )
#
# File ~/Repos/MINT/mineut/MuC.py:1097, in MuDecaySimulator.plot_event_counts_vs_energy(self, detect_loc, detect, nbins, e_bins, log_e, det_radius, figsize, fig_and_ax, xlabel, ylabel, color, label, s_range)
#    1094 from scipy.interpolate import UnivariateSpline as uspline
#    1096 if detect:
# -> 1097     centers, counts = self.get_event_counts_vs_energy(
#    1098         detect_loc=detect_loc,
#    1099         nbins=nbins,
#    1100         e_bins=e_bins,
#    1101         log_e=log_e,
#    1102         det_radius=det_radius,
#    1103     )
#    1104 else:
#    1105     centers, counts = self.get_event_counts_vs_energy_srange(
#    1106         s_range=s_range, nbins=nbins, e_bins=e_bins, log_e=log_e
#    1107     )
#
# File ~/Repos/MINT/mineut/MuC.py:941, in MuDecaySimulator.get_event_counts_vs_energy(self, detect_loc, nbins, e_bins, log_e, det_radius)
#     921 def get_event_counts_vs_energy(
#     922     self,
#     923     detect_loc,
#    (...)
#     927     det_radius=1e2,
#     928 ):
#     929     """Return event counts binned in neutrino energy for the given detector locations.
#     930
#     931     Args:
#    (...)
#     939         the predicted number of neutrino interaction events (weights * P_int) in each bin.
#     940     """
# --> 941     p_dir = self.pnu.to_3D().unit()
#     943     # Store neutrino energies and interaction contributions for events in acceptance
#     944     nu_energies = []
#
# AttributeError: 'MuDecaySimulator' object has no attribute 'pnu'

# %%
fig, ax, _ = combined_numu.plot_event_counts_vs_energy(
    detect=False,
    e_bins=np.geomspace(1e-2, 70, 30),
    s_range=(0,160e2),
    color="green",
    label="PA"
)

combined_numu.plot_event_counts_vs_energy(
    detect=False,
    e_bins=np.geomspace(1e-2, 70, 30),
    s_range=(160e2,1.4e5),
    fig_and_ax=(fig, ax),
    color="red",
    label="RLA1"
)

combined_numu.plot_event_counts_vs_energy(
    detect=False,
    e_bins=np.geomspace(1e-2, 70, 30),
    s_range=(1.4e5,1.699697e6),
    fig_and_ax=(fig, ax),
    color="blue",
    label="RLA2",
    ylabel="E dN/dE (per year)"
)

ax.legend()
ax.set_ylim(1e4, 1e8)
fig.suptitle("Time Integrated Event Rate at Each Accelerator Complex\n (place detectors everywhere)")
plt.show()

fig.savefig('plots/event_rate_spectrum_all.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 fig, ax, _ = combined_numu.plot_event_counts_vs_energy(
#       2     detect=False,
#       3     e_bins=np.geomspace(1e-2, 70, 30),
#       4     s_range=(0,160e2),
#       5     color="green",
#       6     label="PA"
#       7 )
#       9 combined_numu.plot_event_counts_vs_energy(
#      10     detect=False,
#      11     e_bins=np.geomspace(1e-2, 70, 30),
#    (...)
#      15     label="RLA1"
#      16 )
#      18 combined_numu.plot_event_counts_vs_energy(
#      19     detect=False,
#      20     e_bins=np.geomspace(1e-2, 70, 30),
#    (...)
#      25     ylabel="E dN/dE (per year)"
#      26 )
#
# File ~/Repos/MINT/mineut/MuC.py:1105, in MuDecaySimulator.plot_event_counts_vs_energy(self, detect_loc, detect, nbins, e_bins, log_e, det_radius, figsize, fig_and_ax, xlabel, ylabel, color, label, s_range)
#    1097     centers, counts = self.get_event_counts_vs_energy(
#    1098         detect_loc=detect_loc,
#    1099         nbins=nbins,
#    (...)
#    1102         det_radius=det_radius,
#    1103     )
#    1104 else:
# -> 1105     centers, counts = self.get_event_counts_vs_energy_srange(
#    1106         s_range=s_range, nbins=nbins, e_bins=e_bins, log_e=log_e
#    1107     )
#    1109 if fig_and_ax is None:
#    1110     fig, ax = plt.subplots(figsize=figsize)
#
# File ~/Repos/MINT/mineut/MuC.py:1026, in MuDecaySimulator.get_event_counts_vs_energy_srange(self, s_range, nbins, e_bins, log_e)
#    1023 s_min, s_max = s_range
#    1025 # ---- Acceptance mask determined ONLY by muon decay position ----
# -> 1026 in_acceptance = (self.s_muon >= s_min) & (self.s_muon < s_max)
#    1028 if not np.any(in_acceptance):
#    1029     # No events → return empty spectrum
#    1030     if e_bins is None:
#
# AttributeError: 'MuDecaySimulator' object has no attribute 's_muon'
